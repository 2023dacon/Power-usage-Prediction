# %% [markdown]
# # 데이터 불러오기

# %%
pip install pytimekr
# Out:
# Collecting pytimekr
#   Downloading pytimekr-0.1.0.tar.gz (7.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lunardate>=0.1.5 (from pytimekr)
#   Downloading lunardate-0.2.0-py3-none-any.whl (5.6 kB)
# Building wheels for collected packages: pytimekr
#   Building wheel for pytimekr (setup.py) ... done
#   Created wheel for pytimekr: filename=pytimekr-0.1.0-py3-none-any.whl size=7923 sha256=438c64d8fb171ab813724810d30080f97008aa6c178fc87f24a15f4850f4aa70
#   Stored in directory: /root/.cache/pip/wheels/b3/a3/ba/e73aaae1dec550b8667510c379b019295bba855275258745de
# Successfully built pytimekr
# Installing collected packages: lunardate, pytimekr
# Successfully installed lunardate-0.2.0 pytimekr-0.1.0

# %%
import pandas as pd
import numpy as np
from pytimekr import pytimekr
import datetime
from tqdm import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Data/power/
# Out:
# /content/drive/MyDrive/Data/power

# %% [markdown]
# # 데이터 전처리
# ---

# %% [markdown]
# ### train.csv & test.csv

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
train
# Out:
#           num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)  \
# 0         1_20220601 00     1  20220601 00   18.6      NaN      0.9   42.0
# 1         1_20220601 01     1  20220601 01   18.0      NaN      1.1   45.0
# 2         1_20220601 02     1  20220601 02   17.7      NaN      1.5   45.0
# 3         1_20220601 03     1  20220601 03   16.7      NaN      1.4   48.0
# 4         1_20220601 04     1  20220601 04   18.4      NaN      2.8   43.0
# ...                 ...   ...          ...    ...      ...      ...    ...
# 203995  100_20220824 19   100  20220824 19   23.1      NaN      0.9   86.0
# 203996  100_20220824 20   100  20220824 20   22.4      NaN      1.3   86.0
# 203997  100_20220824 21   100  20220824 21   21.3      NaN      1.0   92.0
# 203998  100_20220824 22   100  20220824 22   21.0      NaN      0.3   94.0
# 203999  100_20220824 23   100  20220824 23   20.7      NaN      0.1   95.0
#
#         일조(hr)  일사(MJ/m2)  전력소비량(kWh)
# 0          NaN        NaN     1085.28
# 1          NaN        NaN     1047.36
# 2          NaN        NaN      974.88
# 3          NaN        NaN      953.76
# 4          NaN        NaN      986.40
# ...        ...        ...         ...
# 203995     0.5        NaN      881.04
# 203996     0.0        NaN      798.96
# 203997     NaN        NaN      825.12
# 203998     NaN        NaN      640.08
# 203999     NaN        NaN      540.24
#
# [204000 rows x 10 columns]

# %%
test.head()
# Out:
#    num_date_time  건물번호           일시  기온(C)  강수량(mm)  풍속(m/s)  습도(%)
# 0  1_20220825 00     1  20220825 00   23.5      0.0      2.2     72
# 1  1_20220825 01     1  20220825 01   23.0      0.0      0.9     72
# 2  1_20220825 02     1  20220825 02   22.7      0.0      1.5     75
# 3  1_20220825 03     1  20220825 03   22.1      0.0      1.3     78
# 4  1_20220825 04     1  20220825 04   21.8      0.0      1.0     77

# %% [markdown]
# * 컬럼명 영어로 변환

# %%
train = train.rename(columns={
    '건물번호': 'building_number',
    '일시': 'date_time',
    '기온(C)': 'temperature',
    '강수량(mm)': 'rainfall',
    '풍속(m/s)': 'windspeed',
    '습도(%)': 'humidity',
    '일조(hr)': 'sunshine',
    '일사(MJ/m2)': 'solar_radiation',
    '전력소비량(kWh)': 'power_consumption'
})
test = test.rename(columns={
    '건물번호': 'building_number',
    '일시': 'date_time',
    '기온(C)': 'temperature',
    '강수량(mm)': 'rainfall',
    '풍속(m/s)': 'windspeed',
    '습도(%)': 'humidity'
})
train
# Out:
#           num_date_time  building_number    date_time  temperature  rainfall  \
# 0         1_20220601 00                1  20220601 00         18.6       NaN
# 1         1_20220601 01                1  20220601 01         18.0       NaN
# 2         1_20220601 02                1  20220601 02         17.7       NaN
# 3         1_20220601 03                1  20220601 03         16.7       NaN
# 4         1_20220601 04                1  20220601 04         18.4       NaN
# ...                 ...              ...          ...          ...       ...
# 203995  100_20220824 19              100  20220824 19         23.1       NaN
# 203996  100_20220824 20              100  20220824 20         22.4       NaN
# 203997  100_20220824 21              100  20220824 21         21.3       NaN
# 203998  100_20220824 22              100  20220824 22         21.0       NaN
# 203999  100_20220824 23              100  20220824 23         20.7       NaN
#
#         windspeed  humidity  sunshine  solar_radiation  power_consumption
# 0             0.9      42.0       NaN              NaN            1085.28
# 1             1.1      45.0       NaN              NaN            1047.36
# 2             1.5      45.0       NaN              NaN             974.88
# 3             1.4      48.0       NaN              NaN             953.76
# 4             2.8      43.0       NaN              NaN             986.40
# ...           ...       ...       ...              ...                ...
# 203995        0.9      86.0       0.5              NaN             881.04
# 203996        1.3      86.0       0.0              NaN             798.96
# 203997        1.0      92.0       NaN              NaN             825.12
# 203998        0.3      94.0       NaN              NaN             640.08
# 203999        0.1      95.0       NaN              NaN             540.24
#
# [204000 rows x 10 columns]

# %% [markdown]
# * 일시 -> 월, 일, 요일, 시간으로 분리

# %%
train['date_time'] = pd.to_datetime(train['date_time'], format = '%Y%m%d %H')
test['date_time'] = pd.to_datetime(test['date_time'], format = '%Y%m%d %H')

train['day'] = train['date_time'].dt.day
train['month'] = train['date_time'].dt.month
train['day_of_week'] = train['date_time'].dt.weekday
train['hour'] = train['date_time'].dt.hour

test['day'] = test['date_time'].dt.day
test['month'] = test['date_time'].dt.month
test['day_of_week'] = test['date_time'].dt.weekday
test['hour'] = test['date_time'].dt.hour

train
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour
# 0                 1085.28    1      6            2     0
# 1                 1047.36    1      6            2     1
# 2                  974.88    1      6            2     2
# 3                  953.76    1      6            2     3
# 4                  986.40    1      6            2     4
# ...                   ...  ...    ...          ...   ...
# 203995             881.04   24      8            2    19
# 203996             798.96   24      8            2    20
# 203997             825.12   24      8            2    21
# 203998             640.08   24      8            2    22
# 203999             540.24   24      8            2    23
#
# [204000 rows x 14 columns]

# %%
test.isna().sum()
# Out:
# num_date_time      0
# building_number    0
# date_time          0
# temperature        0
# rainfall           0
# windspeed          0
# humidity           0
# day                0
# month              0
# day_of_week        0
# hour               0
# dtype: int64

# %% [markdown]
# * 풍속, 습도 결측치 처리(_ver2)

# %%
train['windspeed'].fillna(method='ffill', inplace=True)
train['humidity'].fillna(method='ffill', inplace=True)

test['windspeed'].fillna(method='ffill', inplace=True)
test['humidity'].fillna(method='ffill', inplace=True)

# %% [markdown]
# #### 파생변수

# %% [markdown]
# * sin, cos 시간 추가 : 순환성

# %%
train['cos_time'] = np.cos(2 * np.pi * (train['hour']/24))
train['sin_time'] = np.sin(2 * np.pi * (train['hour']/24))

test['cos_time'] = np.cos(2 * np.pi * (test['hour']/24))
test['sin_time'] = np.sin(2 * np.pi * (test['hour']/24))
train
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time
# 0                 1085.28    1      6            2     0  1.000000  0.000000
# 1                 1047.36    1      6            2     1  0.965926  0.258819
# 2                  974.88    1      6            2     2  0.866025  0.500000
# 3                  953.76    1      6            2     3  0.707107  0.707107
# 4                  986.40    1      6            2     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 203995             881.04   24      8            2    19  0.258819 -0.965926
# 203996             798.96   24      8            2    20  0.500000 -0.866025
# 203997             825.12   24      8            2    21  0.707107 -0.707107
# 203998             640.08   24      8            2    22  0.866025 -0.500000
# 203999             540.24   24      8            2    23  0.965926 -0.258819
#
# [204000 rows x 16 columns]

# %% [markdown]
# * 공휴일(주말 포함) 여부(True/False) 분류

# %%
train['date_time'] = pd.to_datetime(train['date_time'], format = '%Y-%m-%d')
test['date_time'] = pd.to_datetime(test['date_time'], format = '%Y-%m-%d')

holidays = pytimekr.holidays(2022)
holiday = list()
for h in holidays:
  holiday.append(str(h))
holiday
# Out:
# ['2022-01-31',
#  '2022-02-01',
#  '2022-02-02',
#  '2022-09-09',
#  '2022-09-10',
#  '2022-09-11',
#  '2022-01-01',
#  '2022-03-01',
#  '2022-05-05',
#  '2022-05-08',
#  '2022-06-06',
#  '2022-08-15',
#  '2022-10-09',
#  '2022-10-03',
#  '2022-12-25']

# %%
def is_holiday(d):
  d = str(d)[:10]
  if d in holiday:
    return True
  else:
    return False

def is_weekend(d):
  d = str(d)[:10]
  d = datetime.datetime.strptime(d, '%Y-%m-%d')
  d = d.weekday()
  if d > 4:
    return True
  else:
    return False

train['holiday'] = [True if(is_holiday(d) or is_weekend(d)) else False for d in train['date_time']]
test['holiday'] = [True if(is_holiday(d) or is_weekend(d)) else False for d in test['date_time']]
train
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time  \
# 0                 1085.28    1      6            2     0  1.000000  0.000000
# 1                 1047.36    1      6            2     1  0.965926  0.258819
# 2                  974.88    1      6            2     2  0.866025  0.500000
# 3                  953.76    1      6            2     3  0.707107  0.707107
# 4                  986.40    1      6            2     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 203995             881.04   24      8            2    19  0.258819 -0.965926
# 203996             798.96   24      8            2    20  0.500000 -0.866025
# 203997             825.12   24      8            2    21  0.707107 -0.707107
# 203998             640.08   24      8            2    22  0.866025 -0.500000
# 203999             540.24   24      8            2    23  0.965926 -0.258819
#
#         holiday
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 203995    False
# 203996    False
# 203997    False
# 203998    False
# 203999    False
#
# [204000 rows x 17 columns]

# %%
train.loc[(train['month'] == 6) & (train['day'] == 6)]
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 120       1_20220606 00                1 2022-06-06 00:00:00         20.2
# 121       1_20220606 01                1 2022-06-06 01:00:00         20.2
# 122       1_20220606 02                1 2022-06-06 02:00:00         19.9
# 123       1_20220606 03                1 2022-06-06 03:00:00         19.3
# 124       1_20220606 04                1 2022-06-06 04:00:00         18.8
# ...                 ...              ...                 ...          ...
# 202099  100_20220606 19              100 2022-06-06 19:00:00         21.9
# 202100  100_20220606 20              100 2022-06-06 20:00:00         20.6
# 202101  100_20220606 21              100 2022-06-06 21:00:00         20.1
# 202102  100_20220606 22              100 2022-06-06 22:00:00         19.6
# 202103  100_20220606 23              100 2022-06-06 23:00:00         18.9
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 120          NaN        1.9      74.0       NaN              NaN
# 121          NaN        2.2      73.0       NaN              NaN
# 122          NaN        2.0      76.0       NaN              NaN
# 123          1.3        1.5      84.0       NaN              NaN
# 124          0.0        2.1      84.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 202099       NaN        2.1      63.0       0.4              NaN
# 202100       NaN        1.5      68.0       0.0              NaN
# 202101       NaN        0.8      70.0       NaN              NaN
# 202102       NaN        0.7      72.0       NaN              NaN
# 202103       NaN        0.9      74.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time  \
# 120               1108.32    6      6            0     0  1.000000  0.000000
# 121               1062.24    6      6            0     1  0.965926  0.258819
# 122                997.44    6      6            0     2  0.866025  0.500000
# 123                964.32    6      6            0     3  0.707107  0.707107
# 124               1003.20    6      6            0     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 202099             767.28    6      6            0    19  0.258819 -0.965926
# 202100             753.36    6      6            0    20  0.500000 -0.866025
# 202101             675.60    6      6            0    21  0.707107 -0.707107
# 202102             584.16    6      6            0    22  0.866025 -0.500000
# 202103             480.72    6      6            0    23  0.965926 -0.258819
#
#         holiday
# 120        True
# 121        True
# 122        True
# 123        True
# 124        True
# ...         ...
# 202099     True
# 202100     True
# 202101     True
# 202102     True
# 202103     True
#
# [2400 rows x 17 columns]

# %%
train['holiday'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# * 건물별, 월별, 요일별, 시간대별 전력사용량 평균(.ver5)

# %%
train_power_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'month', 'hour', 'day_of_week'], aggfunc = np.mean).reset_index()
tqdm.pandas()
train['month_day_hour_mean'] = train.progress_apply(lambda x : train_power_mean.loc[(train_power_mean.building_number == x['building_number'])  & (train_power_mean.month == x['month']) & (train_power_mean.hour == x['hour']) & (train_power_mean.day_of_week == x['day_of_week']) ,'power_consumption'].values[0], axis = 1)

test_power_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'month', 'hour', 'day_of_week'], aggfunc = np.mean).reset_index()
tqdm.pandas()
test['month_day_hour_mean'] = test.progress_apply(lambda x : test_power_mean.loc[(test_power_mean.building_number == x['building_number']) & (train_power_mean.month == x['month']) & (test_power_mean.hour == x['hour']) & (test_power_mean.day_of_week == x['day_of_week']) ,'power_consumption'].values[0], axis = 1)

train
# Out:
# 100%|██████████| 204000/204000 [04:48<00:00, 706.84it/s]
# 100%|██████████| 16800/16800 [00:24<00:00, 697.19it/s]
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time  \
# 0                 1085.28    1      6            2     0  1.000000  0.000000
# 1                 1047.36    1      6            2     1  0.965926  0.258819
# 2                  974.88    1      6            2     2  0.866025  0.500000
# 3                  953.76    1      6            2     3  0.707107  0.707107
# 4                  986.40    1      6            2     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 203995             881.04   24      8            2    19  0.258819 -0.965926
# 203996             798.96   24      8            2    20  0.500000 -0.866025
# 203997             825.12   24      8            2    21  0.707107 -0.707107
# 203998             640.08   24      8            2    22  0.866025 -0.500000
# 203999             540.24   24      8            2    23  0.965926 -0.258819
#
#         holiday  month_day_hour_mean
# 0         False             1174.656
# 1         False             1101.600
# 2         False             1025.760
# 3         False             1015.584
# 4         False             1041.792
# ...         ...                  ...
# 203995    False             1067.700
# 203996    False              951.300
# 203997    False              857.760
# 203998    False              717.240
# 203999    False              616.500
#
# [204000 rows x 18 columns]

# %% [markdown]
# * 건물별, 요일별, 시간대별 전력사용량 평균

# %%
train_power_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour', 'day_of_week'], aggfunc = np.mean).reset_index()
tqdm.pandas()
train['day_hour_mean'] = train.progress_apply(lambda x : train_power_mean.loc[(train_power_mean.building_number == x['building_number']) & (train_power_mean.hour == x['hour']) & (train_power_mean.day_of_week == x['day_of_week']) ,'power_consumption'].values[0], axis = 1)

test_power_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour', 'day_of_week'], aggfunc = np.mean).reset_index()
tqdm.pandas()
test['day_hour_mean'] = test.progress_apply(lambda x : test_power_mean.loc[(test_power_mean.building_number == x['building_number']) & (test_power_mean.hour == x['hour']) & (test_power_mean.day_of_week == x['day_of_week']) ,'power_consumption'].values[0], axis = 1)

train
# Out:
# 100%|██████████| 204000/204000 [03:03<00:00, 1114.26it/s]
# 100%|██████████| 16800/16800 [00:16<00:00, 998.27it/s]
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time  \
# 0                 1085.28    1      6            2     0  1.000000  0.000000
# 1                 1047.36    1      6            2     1  0.965926  0.258819
# 2                  974.88    1      6            2     2  0.866025  0.500000
# 3                  953.76    1      6            2     3  0.707107  0.707107
# 4                  986.40    1      6            2     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 203995             881.04   24      8            2    19  0.258819 -0.965926
# 203996             798.96   24      8            2    20  0.500000 -0.866025
# 203997             825.12   24      8            2    21  0.707107 -0.707107
# 203998             640.08   24      8            2    22  0.866025 -0.500000
# 203999             540.24   24      8            2    23  0.965926 -0.258819
#
#         holiday  month_day_hour_mean  day_hour_mean
# 0         False             1174.656    1774.744615
# 1         False             1101.600    1687.347692
# 2         False             1025.760    1571.483077
# 3         False             1015.584    1522.153846
# 4         False             1041.792    1506.793846
# ...         ...                  ...            ...
# 203995    False             1067.700     964.873846
# 203996    False              951.300     882.184615
# 203997    False              857.760     779.095385
# 203998    False              717.240     663.267692
# 203999    False              616.500     561.932308
#
# [204000 rows x 19 columns]

# %% [markdown]
# * 건물별, 시간별 전력소비량 평균

# %%
train_power_hour_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour'], aggfunc = np.mean).reset_index()
tqdm.pandas()
train['hour_mean'] = train.progress_apply(lambda x : train_power_hour_mean.loc[(train_power_hour_mean.building_number == x['building_number']) & (train_power_hour_mean.hour == x['hour']) ,'power_consumption'].values[0], axis = 1)

test_power_hour_mean = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour'], aggfunc = np.mean).reset_index()
tqdm.pandas()
test['hour_mean'] = test.progress_apply(lambda x : test_power_hour_mean.loc[(test_power_hour_mean.building_number == x['building_number']) & (test_power_hour_mean.hour == x['hour']) ,'power_consumption'].values[0], axis = 1)

train
# Out:
# 100%|██████████| 204000/204000 [02:01<00:00, 1678.29it/s]
# 100%|██████████| 16800/16800 [00:09<00:00, 1801.75it/s]
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  day  month  day_of_week  hour  cos_time  sin_time  \
# 0                 1085.28    1      6            2     0  1.000000  0.000000
# 1                 1047.36    1      6            2     1  0.965926  0.258819
# 2                  974.88    1      6            2     2  0.866025  0.500000
# 3                  953.76    1      6            2     3  0.707107  0.707107
# 4                  986.40    1      6            2     4  0.500000  0.866025
# ...                   ...  ...    ...          ...   ...       ...       ...
# 203995             881.04   24      8            2    19  0.258819 -0.965926
# 203996             798.96   24      8            2    20  0.500000 -0.866025
# 203997             825.12   24      8            2    21  0.707107 -0.707107
# 203998             640.08   24      8            2    22  0.866025 -0.500000
# 203999             540.24   24      8            2    23  0.965926 -0.258819
#
#         holiday  month_day_hour_mean  day_hour_mean    hour_mean
# 0         False             1174.656    1774.744615  1706.318118
# 1         False             1101.600    1687.347692  1622.620235
# 2         False             1025.760    1571.483077  1506.971294
# 3         False             1015.584    1522.153846  1437.365647
# 4         False             1041.792    1506.793846  1447.321412
# ...         ...                  ...            ...          ...
# 203995    False             1067.700     964.873846  1010.462118
# 203996    False              951.300     882.184615   928.125176
# 203997    False              857.760     779.095385   830.032941
# 203998    False              717.240     663.267692   723.100235
# 203999    False              616.500     561.932308   588.784941
#
# [204000 rows x 20 columns]

# %% [markdown]
# * 건물별, 시간별 전력소비량 표준편차

# %%
train_power_hour_std = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour'], aggfunc = np.std).reset_index()
tqdm.pandas()
train['hour_std'] = train.progress_apply(lambda x : train_power_hour_std.loc[(train_power_hour_std.building_number == x['building_number']) & (train_power_hour_std.hour == x['hour']) ,'power_consumption'].values[0], axis = 1)

test_power_hour_std = pd.pivot_table(train, values = 'power_consumption', index = ['building_number', 'hour'], aggfunc = np.std).reset_index()
tqdm.pandas()
test['hour_std'] = test.progress_apply(lambda x : test_power_hour_std.loc[(test_power_hour_std.building_number == x['building_number']) & (test_power_hour_std.hour == x['hour']) ,'power_consumption'].values[0], axis = 1)
# Out:
# 100%|██████████| 204000/204000 [02:00<00:00, 1689.10it/s]
# 100%|██████████| 16800/16800 [00:09<00:00, 1785.11it/s]

# %% [markdown]
# * 불쾌지수
# ---
# 불쾌지수 = 0.81 * temperature + 0.01 * humidity * (0.99 * temperature - 14.3) + 46.3

# %%
train['discomfort'] = 0.81 * train['temperature'] + 0.01 * train['humidity'] * (0.99 * train['temperature'] - 14.3) + 46.3
test['discomfort'] = 0.81 * test['temperature'] + 0.01 * test['humidity'] * (0.99 * test['temperature'] - 14.3) + 46.3
train
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  ...  day_of_week  hour  cos_time  sin_time  \
# 0                 1085.28  ...            2     0  1.000000  0.000000
# 1                 1047.36  ...            2     1  0.965926  0.258819
# 2                  974.88  ...            2     2  0.866025  0.500000
# 3                  953.76  ...            2     3  0.707107  0.707107
# 4                  986.40  ...            2     4  0.500000  0.866025
# ...                   ...  ...          ...   ...       ...       ...
# 203995             881.04  ...            2    19  0.258819 -0.965926
# 203996             798.96  ...            2    20  0.500000 -0.866025
# 203997             825.12  ...            2    21  0.707107 -0.707107
# 203998             640.08  ...            2    22  0.866025 -0.500000
# 203999             540.24  ...            2    23  0.965926 -0.258819
#
#         holiday  month_day_hour_mean  day_hour_mean    hour_mean    hour_std  \
# 0         False             1174.656    1774.744615  1706.318118  446.882767
# 1         False             1101.600    1687.347692  1622.620235  439.662704
# 2         False             1025.760    1571.483077  1506.971294  412.071906
# 3         False             1015.584    1522.153846  1437.365647  391.205981
# 4         False             1041.792    1506.793846  1447.321412  381.099697
# ...         ...                  ...            ...          ...         ...
# 203995    False             1067.700     964.873846  1010.462118  161.399578
# 203996    False              951.300     882.184615   928.125176  137.566008
# 203997    False              857.760     779.095385   830.032941  128.300189
# 203998    False              717.240     663.267692   723.100235  112.464079
# 203999    False              616.500     561.932308   588.784941   91.484424
#
#         discomfort
# 0         63.09388
# 1         62.46400
# 2         62.08735
# 3         60.89884
# 4         62.88788
# ...            ...
# 203995    72.38034
# 203996    71.21736
# 203997    69.79704
# 203998    69.41060
# 203999    68.95035
#
# [204000 rows x 22 columns]

# %% [markdown]
# * 냉방도일(CDH, Cooling Degree Hour)

# %%
def CDH(xs):
    ys = []
    for i in range(len(xs)):
        if i < 11:
            ys.append(np.sum(xs[:(i+1)]-26))
        else:
            ys.append(np.sum(xs[(i-11):(i+1)]-26))
    return np.array(ys)

train_cdhs = np.array([])
test_cdhs = np.array([])

for num in range(1,101,1):
    train_temp = train[train['building_number'] == num]
    test_temp = test[test['building_number'] == num]
    train_cdh = CDH(train_temp['temperature'].values)
    test_cdh = CDH(test_temp['temperature'].values)
    train_cdhs = np.concatenate([train_cdhs, train_cdh])
    test_cdhs = np.concatenate([test_cdhs, test_cdh])
train['CDH'] = train_cdhs
test['CDH'] = test_cdhs
train
# Out:
#           num_date_time  building_number           date_time  temperature  \
# 0         1_20220601 00                1 2022-06-01 00:00:00         18.6
# 1         1_20220601 01                1 2022-06-01 01:00:00         18.0
# 2         1_20220601 02                1 2022-06-01 02:00:00         17.7
# 3         1_20220601 03                1 2022-06-01 03:00:00         16.7
# 4         1_20220601 04                1 2022-06-01 04:00:00         18.4
# ...                 ...              ...                 ...          ...
# 203995  100_20220824 19              100 2022-08-24 19:00:00         23.1
# 203996  100_20220824 20              100 2022-08-24 20:00:00         22.4
# 203997  100_20220824 21              100 2022-08-24 21:00:00         21.3
# 203998  100_20220824 22              100 2022-08-24 22:00:00         21.0
# 203999  100_20220824 23              100 2022-08-24 23:00:00         20.7
#
#         rainfall  windspeed  humidity  sunshine  solar_radiation  \
# 0            NaN        0.9      42.0       NaN              NaN
# 1            NaN        1.1      45.0       NaN              NaN
# 2            NaN        1.5      45.0       NaN              NaN
# 3            NaN        1.4      48.0       NaN              NaN
# 4            NaN        2.8      43.0       NaN              NaN
# ...          ...        ...       ...       ...              ...
# 203995       NaN        0.9      86.0       0.5              NaN
# 203996       NaN        1.3      86.0       0.0              NaN
# 203997       NaN        1.0      92.0       NaN              NaN
# 203998       NaN        0.3      94.0       NaN              NaN
# 203999       NaN        0.1      95.0       NaN              NaN
#
#         power_consumption  ...  hour  cos_time  sin_time  holiday  \
# 0                 1085.28  ...     0  1.000000  0.000000    False
# 1                 1047.36  ...     1  0.965926  0.258819    False
# 2                  974.88  ...     2  0.866025  0.500000    False
# 3                  953.76  ...     3  0.707107  0.707107    False
# 4                  986.40  ...     4  0.500000  0.866025    False
# ...                   ...  ...   ...       ...       ...      ...
# 203995             881.04  ...    19  0.258819 -0.965926    False
# 203996             798.96  ...    20  0.500000 -0.866025    False
# 203997             825.12  ...    21  0.707107 -0.707107    False
# 203998             640.08  ...    22  0.866025 -0.500000    False
# 203999             540.24  ...    23  0.965926 -0.258819    False
#
#         month_day_hour_mean  day_hour_mean    hour_mean    hour_std  \
# 0                  1174.656    1774.744615  1706.318118  446.882767
# 1                  1101.600    1687.347692  1622.620235  439.662704
# 2                  1025.760    1571.483077  1506.971294  412.071906
# 3                  1015.584    1522.153846  1437.365647  391.205981
# 4                  1041.792    1506.793846  1447.321412  381.099697
# ...                     ...            ...          ...         ...
# 203995             1067.700     964.873846  1010.462118  161.399578
# 203996              951.300     882.184615   928.125176  137.566008
# 203997              857.760     779.095385   830.032941  128.300189
# 203998              717.240     663.267692   723.100235  112.464079
# 203999              616.500     561.932308   588.784941   91.484424
#
#         discomfort   CDH
# 0         63.09388  -7.4
# 1         62.46400 -15.4
# 2         62.08735 -23.7
# 3         60.89884 -33.0
# 4         62.88788 -40.6
# ...            ...   ...
# 203995    72.38034 -19.6
# 203996    71.21736 -20.2
# 203997    69.79704 -22.3
# 203998    69.41060 -25.1
# 203999    68.95035 -28.1
#
# [204000 rows x 23 columns]

# %%
test.columns
# Out:
# Index(['num_date_time', 'building_number', 'date_time', 'temperature',
#        'rainfall', 'windspeed', 'humidity', 'day', 'month', 'day_of_week',
#        'hour', 'cos_time', 'sin_time', 'holiday', 'day_hour_mean', 'hour_mean',
#        'hour_std', 'discomfort', 'CDH'],
#       dtype='object')

# %% [markdown]
# * 체감온도(_ver2)

# %%
import math
def get_pow(series):
  return math.pow(series, 0.16)

train['sensory_temperature'] = 13.12 + 0.6215 * train['temperature'] - 11.37 * train['windspeed'].apply(get_pow) + 0.3965 * train['windspeed'].apply(get_pow) * train['temperature']
test['sensory_temperature'] = 13.12 + 0.6215 * test['temperature'] - 11.37 * test['windspeed'].apply(get_pow) + 0.3965 * test['windspeed'].apply(get_pow) * test['temperature']

# %% [markdown]
# * 'num_date_time', '일시', '시간', '강수량(mm)', '일조(hr)', '일사(MJ/m2)' 열 제거

# %%
train = train.drop(['num_date_time', 'date_time', 'hour', 'rainfall', 'sunshine', 'solar_radiation'], axis = 1)
test = test.drop(['num_date_time', 'date_time', 'hour', 'rainfall'], axis = 1)
train
# Out:
#         building_number  temperature  windspeed  humidity  power_consumption  \
# 0                     1         18.6        0.9      42.0            1085.28
# 1                     1         18.0        1.1      45.0            1047.36
# 2                     1         17.7        1.5      45.0             974.88
# 3                     1         16.7        1.4      48.0             953.76
# 4                     1         18.4        2.8      43.0             986.40
# ...                 ...          ...        ...       ...                ...
# 203995              100         23.1        0.9      86.0             881.04
# 203996              100         22.4        1.3      86.0             798.96
# 203997              100         21.3        1.0      92.0             825.12
# 203998              100         21.0        0.3      94.0             640.08
# 203999              100         20.7        0.1      95.0             540.24
#
#         day  month  day_of_week  cos_time  sin_time  holiday  \
# 0         1      6            2  1.000000  0.000000    False
# 1         1      6            2  0.965926  0.258819    False
# 2         1      6            2  0.866025  0.500000    False
# 3         1      6            2  0.707107  0.707107    False
# 4         1      6            2  0.500000  0.866025    False
# ...     ...    ...          ...       ...       ...      ...
# 203995   24      8            2  0.258819 -0.965926    False
# 203996   24      8            2  0.500000 -0.866025    False
# 203997   24      8            2  0.707107 -0.707107    False
# 203998   24      8            2  0.866025 -0.500000    False
# 203999   24      8            2  0.965926 -0.258819    False
#
#         month_day_hour_mean  day_hour_mean    hour_mean    hour_std  \
# 0                  1174.656    1774.744615  1706.318118  446.882767
# 1                  1101.600    1687.347692  1622.620235  439.662704
# 2                  1025.760    1571.483077  1506.971294  412.071906
# 3                  1015.584    1522.153846  1437.365647  391.205981
# 4                  1041.792    1506.793846  1447.321412  381.099697
# ...                     ...            ...          ...         ...
# 203995             1067.700     964.873846  1010.462118  161.399578
# 203996              951.300     882.184615   928.125176  137.566008
# 203997              857.760     779.095385   830.032941  128.300189
# 203998              717.240     663.267692   723.100235  112.464079
# 203999              616.500     561.932308   588.784941   91.484424
#
#         discomfort   CDH  sensory_temperature
# 0         63.09388  -7.4            20.751584
# 1         62.46400 -15.4            20.008954
# 2         62.08735 -23.7            19.476910
# 3         60.89884 -33.0            18.487958
# 4         62.88788 -40.6            19.751534
# ...            ...   ...                  ...
# 203995    72.38034 -19.6            25.302757
# 203996    71.21736 -20.2            24.446518
# 203997    69.79704 -22.3            23.433400
# 203998    69.41060 -25.1            23.661275
# 203999    68.95035 -28.1            23.797169
#
# [204000 rows x 18 columns]

# %%
train[['building_number']] = train[['building_number']].astype('category')
test[['building_number']] = test[['building_number']].astype('category')

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16800 entries, 0 to 16799
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   building_number  16800 non-null  category
#  1   temperature      16800 non-null  float64
#  2   windspeed        16800 non-null  float64
#  3   humidity         16800 non-null  int64
#  4   day              16800 non-null  int64
#  5   month            16800 non-null  int64
#  6   day_of_week      16800 non-null  int64
#  7   cos_time         16800 non-null  float64
#  8   sin_time         16800 non-null  float64
#  9   holiday          16800 non-null  bool
#  10  day_hour_mean    16800 non-null  float64
#  11  hour_mean        16800 non-null  float64
#  12  hour_std         16800 non-null  float64
#  13  discomfort       16800 non-null  float64
#  14  CDH              16800 non-null  float64
# dtypes: bool(1), category(1), float64(9), int64(4)
# memory usage: 1.7 MB

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   building_number    204000 non-null  category
#  1   temperature        204000 non-null  float64
#  2   windspeed          203981 non-null  float64
#  3   humidity           203991 non-null  float64
#  4   power_consumption  204000 non-null  float64
#  5   day                204000 non-null  int64
#  6   month              204000 non-null  int64
#  7   day_of_week        204000 non-null  int64
#  8   cos_time           204000 non-null  float64
#  9   sin_time           204000 non-null  float64
#  10  holiday            204000 non-null  bool
#  11  day_hour_mean      204000 non-null  float64
#  12  hour_mean          204000 non-null  float64
#  13  hour_std           204000 non-null  float64
#  14  discomfort         203991 non-null  float64
#  15  CDH                204000 non-null  float64
# dtypes: bool(1), category(1), float64(11), int64(3)
# memory usage: 22.2 MB

# %% [markdown]
# ### building_info.csv

# %%
building = pd.read_csv("building_info.csv")
building
# Out:
#     건물번호    건물유형    연면적(m2)   냉방면적(m2) 태양광용량(kW) ESS저장용량(kWh) PCS용량(kW)
# 0      1    건물기타  110634.00   39570.00         -            -         -
# 1      2    건물기타  122233.47   99000.00         -            -         -
# 2      3    건물기타  171243.00  113950.00        40            -         -
# 3      4    건물기타   74312.98   34419.62        60            -         -
# 4      5    건물기타  205884.00  150000.00         -         2557      1000
# ..   ...     ...        ...        ...       ...          ...       ...
# 95    96  호텔및리조트   93314.00   60500.00         -            -         -
# 96    97  호텔및리조트   55144.67   25880.00         -            -         -
# 97    98  호텔및리조트   53578.62   17373.75         -            -         -
# 98    99  호텔및리조트   53499.00   40636.00         -            -         -
# 99   100  호텔및리조트   57497.84   40035.23         -            -         -
#
# [100 rows x 7 columns]

# %% [markdown]
# * 컬럼명 영어로 변환

# %%
building = building.rename(columns={
    '건물번호': 'building_number',
    '건물유형': 'building_type',
    '연면적(m2)': 'total_area',
    '냉방면적(m2)': 'cooling_area',
    '태양광용량(kW)': 'solar_power_capacity',
    'ESS저장용량(kWh)': 'ess_capacity',
    'PCS용량(kW)': 'pcs_capacity'
})

# %% [markdown]
# * 건물 타입 영문 매핑

# %%
translation_dict = {
    '건물기타': 'Other Buildings',
    '공공': 'Public',
    '대학교': 'University',
    '데이터센터': 'Data Center',
    '백화점및아울렛': 'Department Store and Outlet',
    '병원': 'Hospital',
    '상용': 'Commercial',
    '아파트': 'Apartment',
    '연구소': 'Research Institute',
    '지식산업센터': 'Knowledge Industry Center',
    '할인마트': 'Discount Mart',
    '호텔및리조트': 'Hotel and Resort'
}

building['building_type'] = building['building_type'].replace(translation_dict)
building
# Out:
#     building_number     building_type  total_area  cooling_area  \
# 0                 1   Other Buildings   110634.00      39570.00
# 1                 2   Other Buildings   122233.47      99000.00
# 2                 3   Other Buildings   171243.00     113950.00
# 3                 4   Other Buildings    74312.98      34419.62
# 4                 5   Other Buildings   205884.00     150000.00
# ..              ...               ...         ...           ...
# 95               96  Hotel and Resort    93314.00      60500.00
# 96               97  Hotel and Resort    55144.67      25880.00
# 97               98  Hotel and Resort    53578.62      17373.75
# 98               99  Hotel and Resort    53499.00      40636.00
# 99              100  Hotel and Resort    57497.84      40035.23
#
#    solar_power_capacity ess_capacity pcs_capacity
# 0                     -            -            -
# 1                     -            -            -
# 2                    40            -            -
# 3                    60            -            -
# 4                     -         2557         1000
# ..                  ...          ...          ...
# 95                    -            -            -
# 96                    -            -            -
# 97                    -            -            -
# 98                    -            -            -
# 99                    -            -            -
#
# [100 rows x 7 columns]

# %% [markdown]
# * 결측치 처리

# %%
len(building.loc[building['solar_power_capacity'] == '-'])
# Out:
# 64

# %%
len(building.loc[building['ess_capacity'] == '-'])
# Out:
# 95

# %%
len(building.loc[building['pcs_capacity'] == '-'])
# Out:
# 95

# %%
building.replace('-', np.nan)
building
# Out:
#     building_number     building_type  total_area  cooling_area  \
# 0                 1   Other Buildings   110634.00      39570.00
# 1                 2   Other Buildings   122233.47      99000.00
# 2                 3   Other Buildings   171243.00     113950.00
# 3                 4   Other Buildings    74312.98      34419.62
# 4                 5   Other Buildings   205884.00     150000.00
# ..              ...               ...         ...           ...
# 95               96  Hotel and Resort    93314.00      60500.00
# 96               97  Hotel and Resort    55144.67      25880.00
# 97               98  Hotel and Resort    53578.62      17373.75
# 98               99  Hotel and Resort    53499.00      40636.00
# 99              100  Hotel and Resort    57497.84      40035.23
#
#    solar_power_capacity ess_capacity pcs_capacity
# 0                     -            -            -
# 1                     -            -            -
# 2                    40            -            -
# 3                    60            -            -
# 4                     -         2557         1000
# ..                  ...          ...          ...
# 95                    -            -            -
# 96                    -            -            -
# 97                    -            -            -
# 98                    -            -            -
# 99                    -            -            -
#
# [100 rows x 7 columns]

# %%
building = building.fillna(0)
building = building.replace('-', 0)
building
# Out:
#     building_number     building_type  total_area  cooling_area  \
# 0                 1   Other Buildings   110634.00      39570.00
# 1                 2   Other Buildings   122233.47      99000.00
# 2                 3   Other Buildings   171243.00     113950.00
# 3                 4   Other Buildings    74312.98      34419.62
# 4                 5   Other Buildings   205884.00     150000.00
# ..              ...               ...         ...           ...
# 95               96  Hotel and Resort    93314.00      60500.00
# 96               97  Hotel and Resort    55144.67      25880.00
# 97               98  Hotel and Resort    53578.62      17373.75
# 98               99  Hotel and Resort    53499.00      40636.00
# 99              100  Hotel and Resort    57497.84      40035.23
#
#    solar_power_capacity ess_capacity pcs_capacity
# 0                     0            0            0
# 1                     0            0            0
# 2                    40            0            0
# 3                    60            0            0
# 4                     0         2557         1000
# ..                  ...          ...          ...
# 95                    0            0            0
# 96                    0            0            0
# 97                    0            0            0
# 98                    0            0            0
# 99                    0            0            0
#
# [100 rows x 7 columns]

# %% [markdown]
# * pcs 용량 컬럼 삭제
# ---
# pcs 용량은 ess의 속해있는 개념이기 때문에 상관성이 매우 높으므로 제거

# %%
building = building.drop('pcs_capacity', axis = 1)
building
# Out:
#     building_number     building_type  total_area  cooling_area  \
# 0                 1   Other Buildings   110634.00      39570.00
# 1                 2   Other Buildings   122233.47      99000.00
# 2                 3   Other Buildings   171243.00     113950.00
# 3                 4   Other Buildings    74312.98      34419.62
# 4                 5   Other Buildings   205884.00     150000.00
# ..              ...               ...         ...           ...
# 95               96  Hotel and Resort    93314.00      60500.00
# 96               97  Hotel and Resort    55144.67      25880.00
# 97               98  Hotel and Resort    53578.62      17373.75
# 98               99  Hotel and Resort    53499.00      40636.00
# 99              100  Hotel and Resort    57497.84      40035.23
#
#    solar_power_capacity ess_capacity
# 0                     0            0
# 1                     0            0
# 2                    40            0
# 3                    60            0
# 4                     0         2557
# ..                  ...          ...
# 95                    0            0
# 96                    0            0
# 97                    0            0
# 98                    0            0
# 99                    0            0
#
# [100 rows x 6 columns]

# %% [markdown]
# * buildiing_number, building_type category화

# %%
building['building_number'] = building['building_number'].astype('category')
building['building_type'] = building['building_type'].astype('category')

# %% [markdown]
# ## 데이터 병합

# %%
train_df = pd.merge(train, building, on = 'building_number', how = 'left' )
test_df = pd.merge(test, building, on = 'building_number', how = 'left')
train_df
# Out:
#        building_number  temperature  windspeed  humidity  power_consumption  \
# 0                    1         18.6        0.9      42.0            1085.28
# 1                    1         18.0        1.1      45.0            1047.36
# 2                    1         17.7        1.5      45.0             974.88
# 3                    1         16.7        1.4      48.0             953.76
# 4                    1         18.4        2.8      43.0             986.40
# ...                ...          ...        ...       ...                ...
# 203995             100         23.1        0.9      86.0             881.04
# 203996             100         22.4        1.3      86.0             798.96
# 203997             100         21.3        1.0      92.0             825.12
# 203998             100         21.0        0.3      94.0             640.08
# 203999             100         20.7        0.1      95.0             540.24
#
#         day  month  day_of_week  cos_time  sin_time  ...    hour_mean  \
# 0         1      6            2  1.000000  0.000000  ...  1706.318118
# 1         1      6            2  0.965926  0.258819  ...  1622.620235
# 2         1      6            2  0.866025  0.500000  ...  1506.971294
# 3         1      6            2  0.707107  0.707107  ...  1437.365647
# 4         1      6            2  0.500000  0.866025  ...  1447.321412
# ...     ...    ...          ...       ...       ...  ...          ...
# 203995   24      8            2  0.258819 -0.965926  ...  1010.462118
# 203996   24      8            2  0.500000 -0.866025  ...   928.125176
# 203997   24      8            2  0.707107 -0.707107  ...   830.032941
# 203998   24      8            2  0.866025 -0.500000  ...   723.100235
# 203999   24      8            2  0.965926 -0.258819  ...   588.784941
#
#           hour_std  discomfort   CDH  sensory_temperature     building_type  \
# 0       446.882767    63.09388  -7.4            20.751584   Other Buildings
# 1       439.662704    62.46400 -15.4            20.008954   Other Buildings
# 2       412.071906    62.08735 -23.7            19.476910   Other Buildings
# 3       391.205981    60.89884 -33.0            18.487958   Other Buildings
# 4       381.099697    62.88788 -40.6            19.751534   Other Buildings
# ...            ...         ...   ...                  ...               ...
# 203995  161.399578    72.38034 -19.6            25.302757  Hotel and Resort
# 203996  137.566008    71.21736 -20.2            24.446518  Hotel and Resort
# 203997  128.300189    69.79704 -22.3            23.433400  Hotel and Resort
# 203998  112.464079    69.41060 -25.1            23.661275  Hotel and Resort
# 203999   91.484424    68.95035 -28.1            23.797169  Hotel and Resort
#
#         total_area  cooling_area solar_power_capacity  ess_capacity
# 0        110634.00      39570.00                    0             0
# 1        110634.00      39570.00                    0             0
# 2        110634.00      39570.00                    0             0
# 3        110634.00      39570.00                    0             0
# 4        110634.00      39570.00                    0             0
# ...            ...           ...                  ...           ...
# 203995    57497.84      40035.23                    0             0
# 203996    57497.84      40035.23                    0             0
# 203997    57497.84      40035.23                    0             0
# 203998    57497.84      40035.23                    0             0
# 203999    57497.84      40035.23                    0             0
#
# [204000 rows x 23 columns]

# %%
train_df.columns
# Out:
# Index(['building_number', 'temperature', 'windspeed', 'humidity',
#        'power_consumption', 'day', 'month', 'day_of_week', 'cos_time',
#        'sin_time', 'holiday', 'day_hour_mean', 'hour_mean', 'hour_std',
#        'discomfort', 'CDH', 'building_type', 'total_area', 'cooling_area',
#        'solar_power_capacity', 'ess_capacity'],
#       dtype='object')

# %%
train_df.to_csv("pre_train.csv")
test_df.to_csv("pre_test.csv")
