# %% [markdown]
# Feature Selction 기준 (One-Hot Encoding) (Standard Scaling)
#
# 1. 종속 변수와의 상관관계 (영향력 훑기 및 다중공선성 예방 feature 제거를 위함)
#
# 2. XGB 변수중요도
#
# 3. RF 변수중요도
#
# 4. XGB RFECV
#
# 5. Lasso, Lidge
#
# 6. shap (참고 : https://www.kaggle.com/code/bryanb/xgboost-explainability-with-shap)
# https://topo314.tistory.com/87
#
# shap 공홈 https://shap.readthedocs.io/en/latest/index.html
#
# 후에 Label 인코딩, mean 인코딩도 진행해 볼 예정

# %% [markdown]
# 모델 평가 기준
#
# 1. train set 기준 8: 2 = train : test, randomstate=42
#
# 2. test set 예측 및 제출

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import array

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import MinMaxScaler

from xgboost import XGBRegressor

# %%
df = pd.read_csv('./data/pp_train_v03.csv', encoding='utf-8')
df
# Out:
#         building_number  temperature  windspeed  humidity  power_consumption  \
# 0                     1         18.6        0.9      42.0            1085.28
# 1                     1         18.0        1.1      45.0            1047.36
# 2                     1         17.7        1.5      45.0             974.88
# 3                     1         16.7        1.4      48.0             953.76
# 4                     1         18.4        2.8      43.0             986.40
# ...                 ...          ...        ...       ...                ...
# 203995              100         26.2        2.0      93.0            1232.64
# 203996              100         25.8        2.0      94.0            1103.28
# 203997              100         25.6        0.7      95.0             964.56
# 203998              100         25.4        1.7      97.0             773.28
# 203999              100         25.0        0.4      99.0             605.52
#
# ...

# %%
plt.rc('font', family='Malgun Gothic')
plt.rc('font', size=15)
plt.rc('axes', unicode_minus=False)


corr_matrix = df.corr()
corr_matrix = corr_matrix.sort_values(by = 'power_consumption', axis = 0, ascending=False)
corr_matrix = corr_matrix[corr_matrix.index]

# 상관관계의 시각적 표현
f, ax = plt.subplots(figsize=(30, 30))
corr = df.select_dtypes(exclude=["object","bool"]).corr()

# 대각 행렬을 기준으로 한 쪽만 나타나게 설정해줍니다.
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

g = sns.heatmap(corr_matrix, cmap='RdYlGn_r', vmax= 1, mask=mask, 
center=0, annot=True, fmt='.2f', square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title("Diagonal Correlation HeatMap")
# Out:
# C:\Users\magne\AppData\Local\Temp/ipykernel_17400/4083026822.py:15: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(corr_matrix, dtype=np.bool)
# Text(0.5, 1.0, 'Diagonal Correlation HeatMap')

# %%
df.describe()
# Out:
#        building_number    temperature      windspeed       humidity  \
# count    204000.000000  204000.000000  204000.000000  204000.000000
# mean         50.500000      25.543524       2.134052      78.716518
# std          28.866141       3.779523       1.358146      15.080496
# min           1.000000      10.100000       0.000000      13.000000
# 25%          25.750000      23.400000       1.200000      69.000000
# 50%          50.500000      25.700000       2.000000      81.000000
# 75%          75.250000      28.100000       2.800000      91.000000
# max         100.000000      37.100000      13.300000     100.000000
#
#        power_consumption    total_area  cooling_area  solar_power_capacity  \
# count      204000.000000  2.040000e+05  2.040000e+05         204000.000000
# mean         2451.036462  2.608875e+05  1.864032e+05             35.678400
# std          2440.648858  1.273550e+06  1.085174e+06             89.696667
# ...

# %% [markdown]
# 전체면적, 냉방면적의 상관관계가 매우 높지만 다중공선성을 의식하지 않고 진행할 예정

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   building_number       204000 non-null  int64
#  1   temperature           204000 non-null  float64
#  2   windspeed             204000 non-null  float64
#  3   humidity              204000 non-null  float64
#  4   power_consumption     204000 non-null  float64
#  5   building_type         204000 non-null  object
#  6   total_area            204000 non-null  float64
#  7   cooling_area          204000 non-null  float64
#  8   solar_power_capacity  204000 non-null  float64
#  9   ess_capacity          204000 non-null  float64
#  10  pcs_capacity          204000 non-null  float64
#  11  hour                  204000 non-null  int64
#  12  day                   204000 non-null  int64
#  13  month                 204000 non-null  int64
# ...

# %%
df['building_type'] = df['building_type'].astype('category')

# %%
df_encoded = pd.get_dummies(df)
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204000 entries, 0 to 203999
# Data columns (total 47 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   building_number                            204000 non-null  int64
#  1   temperature                                204000 non-null  float64
#  2   windspeed                                  204000 non-null  float64
#  3   humidity                                   204000 non-null  float64
#  4   power_consumption                          204000 non-null  float64
#  5   total_area                                 204000 non-null  float64
#  6   cooling_area                               204000 non-null  float64
#  7   solar_power_capacity                       204000 non-null  float64
#  8   ess_capacity                               204000 non-null  float64
# ...

# %%
# train set, test set 셋팅

from sklearn.preprocessing import StandardScaler

X = df_encoded.drop('power_consumption', axis=1)
y = df_encoded['power_consumption']

scaler = StandardScaler()
s_X = scaler.fit_transform(np.array(X))
s_y = scaler.fit_transform(np.array(y).reshape(-1,1))

X_train, X_test, y_train, y_test = train_test_split(s_X, s_y, random_state=42)
cols = X.columns


print(X_train.shape)
# Out:
# (153000, 46)

# %%
xgbr = XGBRegressor()
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
importance = xgbr.feature_importances_
feature = cols
importances = pd.DataFrame()
importances['feature'] = feature
importances['importances'] = importance
importances.sort_values('importances', ascending=False, inplace=True)
importances.reset_index(drop=True, inplace=True)
importances
# Out:
#                                       feature  importances
# 0                   building_type_Data Center     0.623683
# 1                                  total_area     0.090205
# 2            building_type_Research Institute     0.063514
# 3                     building_type_Apartment     0.038825
# 4                             building_number     0.034113
# 5                    building_type_University     0.033509
# 6                      building_type_Hospital     0.030924
# 7   building_type_Department Store and Outlet     0.013507
# 8                                cooling_area     0.011311
# 9                                        hour     0.007870
# 10                                    holiday     0.006482
# 11                               discomfort_3     0.006285
# 12                              temperature_3     0.005948
# 13                                 discomfort     0.005750
# 14                   building_type_Commercial     0.005032
# ...

# %% [markdown]
# # XGB 변수중요도 결과

# %%
from sklearn.ensemble import RandomForestRegressor


rf = RandomForestRegressor(n_estimators=100, random_state=0)

rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
# Out:
# C:\Users\magne\AppData\Local\Temp/ipykernel_17400/1239765443.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf.fit(X_train, y_train)

# %%
importance = rf.feature_importances_
feature = cols
importances = pd.DataFrame()
importances['feature'] = feature
importances['importances'] = importance
importances.sort_values('importances', ascending=False, inplace=True)
importances.reset_index(drop=True, inplace=True)
importances
# Out:
#                                       feature  importances
# 0                                cooling_area     0.231980
# 1                                  total_area     0.203229
# 2                             building_number     0.143692
# 3                                    solar_no     0.110254
# 4                   building_type_Data Center     0.094200
# 5                                        hour     0.071882
# 6                        solar_power_capacity     0.039384
# 7            building_type_Research Institute     0.019864
# 8                                     holiday     0.019694
# 9                    building_type_University     0.012212
# 10                                 discomfort     0.011701
# 11                     building_type_Hospital     0.008479
# 12                    building_type_Apartment     0.008321
# 13                                   ma_dis_5     0.002281
# 14                                   ma_dis_3     0.002154
# ...

# %% [markdown]
# # RF 변수중요도 결과

# %%
from sklearn.feature_selection import RFECV

estimator = XGBRegressor()

selector = RFECV(estimator, step=1, min_features_to_select=1, cv=5, scoring='neg_mean_absolute_error')

#fit the model, get a rank of the variables, and a matrix of the selected X variables
selector = selector.fit(X_train, y_train)

a = selector.support_.reshape(1,-1)
df_a = pd.DataFrame(columns=cols, data=a)
true_columns = df_a.columns[df_a.iloc[0]].tolist()

print(true_columns)
# Out:
# ['building_number', 'temperature', 'windspeed', 'total_area', 'cooling_area', 'solar_power_capacity', 'ess_capacity', 'pcs_capacity', 'hour', 'day', 'month', 'discomfort', 'temperature_3', 'discomfort_3', 'holiday', 'ma_dis_3', 'ma_dis_5', 'CDH', 'building_type_Apartment', 'building_type_Commercial', 'building_type_Data Center', 'building_type_Department Store and Outlet', 'building_type_Discount Mart', 'building_type_Hospital', 'building_type_Knowledge Industry Center', 'building_type_Public', 'building_type_Research Institute', 'building_type_University']

# %% [markdown]
# 작업시간이 너무 길어져 슈퍼컴 사용

# %% [markdown]
# # XGB RFECV 결과

# %%
from sklearn.linear_model import Ridge, Lasso


ridge_alpha = 0.01
lasso_alpha = 0.001

rid = Ridge(alpha = ridge_alpha)
las = Lasso(alpha = lasso_alpha)

rid.fit(X_train,y_train)
las.fit(X_train,y_train)

rid.coef_, las.coef_
# Out:
# (array([[-1.85990385e+00,  2.09515597e-01,  9.95528380e-02,
#           2.66575633e-02, -1.12860813e+00,  1.15890266e+00,
#           7.33332588e-02, -2.25877459e-01,  3.12571061e-01,
#           5.16533268e-02,  1.92556845e-02,  4.03367212e-02,
#           4.30439897e-02,  1.34038926e-01, -6.10188662e+00,
#           9.05810600e-03, -3.31902233e-02, -3.30115677e-02,
#          -1.45365760e-02, -1.27681396e-02, -1.64703364e-02,
#           2.20763856e-03, -1.51492847e-02, -1.65827670e-04,
#           3.50504482e-01,  6.43749457e-01, -5.17449206e-03,
#          -5.39531926e-02,  6.39242489e+00, -3.23978141e-01,
#          -1.50982379e-01,  8.29369939e-02, -2.48925436e-01,
#           1.77794351e-01,  1.15083137e-01,  6.21325347e-02,
#           1.14299979e-02, -1.96593757e-01,  5.39484493e-01,
#           3.19700267e-03,  6.83693958e-01,  4.60984324e-01,
#          -1.06570266e+00, -6.34555573e-01,  4.21598449e-01,
#          -6.15471327e-02]]),
# ...

# %%
a = rid.coef_.reshape(1,-1)
df_a = pd.DataFrame(columns=X.columns, data=a)
df_a
# Out:
#    building_number  temperature  windspeed  humidity  total_area  \
# 0        -1.859904     0.209516   0.099553  0.026658   -1.128608
#
#    cooling_area  solar_power_capacity  ess_capacity  pcs_capacity      hour  \
# 0      1.158903              0.073333     -0.225877      0.312571  0.051653
#
#    ...  building_type_Data Center  building_type_Department Store and Outlet  \
# 0  ...                    0.01143                                  -0.196594
#
#    building_type_Discount Mart  building_type_Hospital  \
# 0                     0.539484                0.003197
#
#    building_type_Hotel and Resort  building_type_Knowledge Industry Center  \
# 0                        0.683694                                 0.460984
#
#    building_type_Other Buildings  building_type_Public  \
# 0                      -1.065703             -0.634556
#
#    building_type_Research Institute  building_type_University
# 0                          0.421598                 -0.061547
#
# ...

# %%
aaa = df_a.columns.tolist()

fli=[]
coli=[]
for i, col in enumerate(aaa) :
    fli.append(col)
    coli.append(df_a.iloc[0,i])
    
dd = pd.DataFrame({'feature':fli, 'coef':coli})

dd.sort_values('coef', ascending=False, inplace=True)
dd.reset_index(drop=True, inplace=True)
dd
# Out:
#                                       feature      coef
# 0                                    ma_dis_3  6.392425
# 1                                cooling_area  1.158903
# 2              building_type_Hotel and Resort  0.683694
# 3                                discomfort_2  0.643749
# 4                 building_type_Discount Mart  0.539484
# 5     building_type_Knowledge Industry Center  0.460984
# 6            building_type_Research Institute  0.421598
# 7                                discomfort_1  0.350504
# 8                                pcs_capacity  0.312571
# 9                                 temperature  0.209516
# 10                                   CDH_mean  0.177794
# 11                                     ess_no  0.134039
# 12                    building_type_Apartment  0.115083
# 13                                  windspeed  0.099553
# 14                           temperature_mean  0.082937
# 15                       solar_power_capacity  0.073333
# ...

# %% [markdown]
# # Ridge 회귀 결과

# %%
b = las.coef_.reshape(1,-1)
df_b = pd.DataFrame(columns=X.columns, data=b)
# df_b
true_columns = df_b.columns[df_b.iloc[0] != 0].tolist()
print(true_columns)
# Out:
# ['building_number', 'temperature', 'windspeed', 'cooling_area', 'solar_power_capacity', 'ess_capacity', 'pcs_capacity', 'hour', 'day', 'month', 'solar_no', 'ess_no', 'discomfort', 'windspeed_1', 'windspeed_2', 'windspeed_3', 'humidity_3', 'discomfort_2', 'discomfort_3', 'holiday', 'CDH', 'temperature_mean', 'discomfort_mean', 'CDH_mean', 'building_type_Apartment', 'building_type_Data Center', 'building_type_Department Store and Outlet', 'building_type_Discount Mart', 'building_type_Hospital', 'building_type_Hotel and Resort', 'building_type_Knowledge Industry Center', 'building_type_Other Buildings', 'building_type_Public', 'building_type_Research Institute', 'building_type_University']

# %% [markdown]
# # Lasso 회귀 결과

# %% [markdown]
# # Shap value
#
# -shap value: inconsistency한 문제를 해결하기 위한 지표
#
# 1. 정의
#
# -(연합 게임 이론)goal을 성취하기 위해 player들이 협업하여, 전체 payout에 대해 각 player들의 기여도에 따라 payout을 배당
#    => goal=prediction, player=feature, payout=feature attribution
#
# -특정 관측치의 j번째 feature로 인한 실제 예측치와 평균 예측치의 평균적인 차이
#
# -목적: 실제 예측값과 평균 예측값의 차이를 변수별 효과로 설명하는 것
#
#     1) A, B, C 변수를 고정(연합)으로 하고, 나머지 변수를 무작위(랜덤)로 뽑아 예측값1 계산
#
#     2) B, C만 고정으로 하고, A를 포함한 나머지 변수를 무작위로 뽑아 예측값2 계산
#
#     3) A 변수의 marginal contribution = 예측값1 - 예측값2
#
#       => 샘플링된 변수들에 따라 이 값이 달라짐
#
#     4) 이 과정을 반복하여 weighted average를 구한 값이 shap value
#
# 2. 특징
#
# -consistency함(feature importance의 단점 보완)
#
#     => 모델이 바뀌어도 shap value값이 달라지지 않음(일치성이 있음)
#
# -특정 관측치 별로 feature가 어떻게 영향을 미치는지 개별적으로 볼 수 있음
#
# -다양한 변수들의 조합을 시각화하여 영향력을 파악하기 쉬움
#
# 3. 해석
#
# -feature contribution이 양수이면 평균 예측치에 비해 긍정적인 효과
#
# -feature contribution이 음수이면 평균 예측치에 비해 부정적인 효과
#
# 'feature contribution이 양수인 변수의 값을 높이면 Y가 증가한다'고 해석X(회귀분석도 마찬가지)
#
#    => 예측을 하는 것이지 인과관계를 보는 것이 아님
#
# -'feature contribution이 양수인 변수의 값이 높을수록 Y가 평균치보다 클 확률이 높아진다(경향이 높다)'고 해석

# %%
# pip install shap
# Out:
# Looking in indexes: http://ftp.daumkakao.com/pypi/simpleNote: you may need to restart the kernel to use updated packages.
# WARNING: Error parsing requirements for plotly: [Errno 2] No such file or directory: 'c:\\users\\magne\\anaconda3\\lib\\site-packages\\plotly-5.9.0.dist-info\\METADATA'
# ...

# %%
# pip install numpy==1.20
# Out:
# Looking in indexes: http://ftp.daumkakao.com/pypi/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
np.__version__
# Out:
# '1.20.0'

# %%
# import shap

# shap.initjs()

# explainer = shap.TreeExplainer(xgbr)
# shap_values = explainer.shap_values(X_train)

shap.force_plot(explainer.expected_value, shap_values[0,:], X_train[0,:])
# Out:
# <div id='i40LS01Y2ADYMHKU0Z937'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# shap.summary_plot(shap_values, X_train)
shap.summary_plot(shap_values, cols)

# %%
shap.summary_plot(shap_values, cols, plot_type="bar")
